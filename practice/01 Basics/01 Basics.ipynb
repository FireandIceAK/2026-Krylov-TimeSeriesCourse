# %% [markdown]
# # Анализ и прогнозирование временных рядов методами искусственного интеллекта
#
# ## **Практическая работа 1. Метрики и меры схожести между временными рядами.**

# %% [markdown]
# Смените рабочую директорию с помощью команды `chdir()`. Для этого передайте этой команде свой путь до каталога, в котором содержатся материалы первой практической работы. После выполнения этой команды все последующие операции с файлами и каталогами будут производиться относительно указанного каталога.

# %%
import os

practice_dir_path = '/Users/anatolijkrylov/Documents/2026---TimeSeriesCourse/practice/01 Basics'
os.chdir(practice_dir_path)

# %% [markdown]
# Выполните команды, которые автоматически перезагружают все импортированные модули при их изменении.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Импортируйте библиотеки и модули, необходимые для реализации практической работы 1.

# %%
# !pip install sktime
# Out:
# Requirement already satisfied: sktime in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.2.0)
# Requirement already satisfied: joblib<1.7,>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from sktime) (1.6.0)
# Requirement already satisfied: numpy<2.6,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from sktime) (2.5.3)
# Requirement already satisfied: packaging in /Users/anatolijkrylov/Library/Python/3.14/lib/python/site-packages (from sktime) (26.3)
# Requirement already satisfied: pandas<3.1.0,>=1.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from sktime) (3.0.6)
# Requirement already satisfied: scikit-base<1.2.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from sktime) (1.1.1)
# Requirement already satisfied: scikit-learn<1.10.0,>=0.24 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from sktime) (1.9.1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from sktime) (1.18.1)
# Requirement already satisfied: cloudpickle>=3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from joblib<1.7,>=1.2.0->sktime) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anatolijkrylov/Library/Python/3.14/lib/python/site-packages (from pandas<3.1.0,>=1.5->sktime) (2.9.0.post0)
# Requirement already satisfied: narwhals>=2.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn<1.10.0,>=0.24->sktime) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn<1.10.0,>=0.24->sktime) (3.7.0)
# Requirement already satisfied: six>=1.5 in /Users/anatolijkrylov/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas<3.1.0,>=1.5->sktime) (1.17.0)

# %%
import numpy as np
import pandas as pd
import random
from sktime.dists_kernels._numba_distances import (
    euclidean_distance,
    dtw_distance,
    pairwise_distance,
)
from sklearn.metrics import silhouette_score
import cv2
import imutils
import glob
import matplotlib.pyplot as plt

from modules.metrics import ED_distance, norm_ED_distance, DTW_distance
from modules.pairwise_distance import PairwiseDistance
from modules.clustering import TimeSeriesHierarchicalClustering
from modules.classification import TimeSeriesKNN, calculate_accuracy
from modules.image_converter import image2ts
from modules.utils import read_ts, z_normalize, sliding_window, random_walk
from modules.plots import plot_ts

# %% [markdown]
# ## **Часть 1.** Функции расстояния: евклидова метрика и DTW мера. Матрица расстояний. Иерархическая кластеризация временных рядов.

# %% [markdown]
# ### **Задача 1.**
# Реализуйте самостоятельно функцию `ED_distance()` в модуле *metrics.py*, которая вычисляет евклидово расстояние между двумя временными рядами, имеющими одинаковую длину. В качестве входных данных передайте в функцию два синтетических временных ряда некоторой заданной вами длины. Для их генерации используйте функцию `random_walk()` из модуля *utils.py*,  реализующую модель случайных блужданий (Random Walk), или стандартный модуль *random*.
#
# **Евклидово расстояние** между двумя временными рядами $T_1$ и $T_2$ длины $n$ вычисляется следующим образом:
#
# \begin{equation}
#     \text{ED}(T_1, T_2) = \sqrt{\sum_{i=1}^{n} ({t_{1}}_i-{t_{2}}_i)^2}.
# \end{equation}
#
# Проверьте реализацию функции, сравнив свои результаты с результатами функции [`euclidean_distance()`](https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.distances.euclidean_distance.html) из библиотеки *sktime*, с помощью `test_distances()`.

# %%
def test_distances(dist1: float, dist2: float) -> None:
    """
    Check whether your distance function is implemented correctly

    Parameters
    ----------
    dist1 : distance between two time series calculated by sktime
    dist2 : distance between two time series calculated by your function
    """

    np.testing.assert_equal(round(dist1, 5), round(dist2, 5), 'Distances are not equal')

# %%
random.seed(0)
ts1 = random_walk(30)
ts2 = random_walk(30)

test_distances(euclidean_distance(ts1, ts2), ED_distance(ts1, ts2))
print("ED distance:", ED_distance(ts1, ts2))
# Out:
# ED distance: 48.16637831516918

# %% [markdown]
# ### **Задача 2.**
#
# Реализуйте самостоятельно функцию `DTW_distance()` в модуле *metrics.py*, которая вычисляет DTW расстояние между двумя временными рядами, имеющими одинаковую длину. Для вычисления расстояния между элементами временных рядов в DTW мере используйте евклидово расстояние. Временные ряды сгенерируйте аналогичным образом, как в задаче 1, или используйте уже созданные.
#
# **Динамическая трансформация временной шкалы (Dynamic Time Warping, DTW)** – мера схожести между двумя временными рядами $T_1$ и $T_2$ длины $n$, вычисляемая следующим образом:
#
# \begin{equation}
# \text{DTW}(T_1, T_2) = d(n,n),
# \\ d(i,j) = ({t_{1}}_i - {t_{2}}_j)^2 + \min \left\{
# 	\begin{array}{l l}
# 	d(i-1,j), \\
# 	d(i,j-1), \\
# 	d(i-1,j-1),
# 	\end{array}
# 	\right.
# \\ d(0,0)=0, \quad d(i,0)=d(0,j)=\infty, \quad  1 \leqslant i,j \leqslant n.
# \end{equation}
#
# Сравните свои результаты с результатами функции [`dtw_distance()`](https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.distances.dtw_distance.html) из библиотеки *sktime*. Для этого используйте `test_distances()` из задачи 1.

# %%
# Те же ряды, что в задаче 1. Локальная стоимость — квадрат разности, как в формуле DTW.
test_distances(dtw_distance(ts1, ts2), DTW_distance(ts1, ts2))
print("DTW distance:", DTW_distance(ts1, ts2))
# Out:
# DTW distance: 2270.0

# %% [markdown]
# ### **Задача 3.**
# Реализуйте нахождение матрицы расстояний между несколькими временными рядами.
# Для этого заполните все методы c недостающим кодом в классе `PairwiseDistance` из модуля *pairwise_distance.py*. Для вычисления расстояний между рядами используйте ранее реализованные вами функции `ED_distance()` и `DTW_distance()` из модуля *metrics.py*.
#
# Матрица расстояний между временными рядами определяется следующим образом. Пусть дано множество $S$, состоящее из $K$ временных рядов длины $n$: $\;S = \{T_1, T_2, ..., T_K\}, \; T_i \in \mathbb{R}^n$. Тогда под **матрицей расстояний** $D \in \mathbb{R}^{K \times K}$ понимается квадратная матрица, где каждый ее элемент $d(i,j)$ представляет собой расстояние между временными рядами $T_i$ и $T_j$ из множества $S$:
# \begin{equation}
# d(i,j) = dist(T_i, T_j), \quad T_i, T_j \in S, \quad 1 \leqslant i,j \leqslant K.
# \end{equation}
#
# Поскольку евклидова метрика и DTW мера удовлетворяют аксиоме симметричности (т.е. $dist(T_i, T_j)=dist(T_j, T_i)$), то матрица расстояний $D$ будет симметричной относительно главной диагонали. Для ускорения вычислений достаточно найти ее верхний треугольник, а нижний треугольник матрицы заполнить значениями верхнего треугольника следующим образом:
# \begin{equation}
# d(j,i) = d(i,j), \; где \; i < j.
# \end{equation}
#
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/01%20Basics/img/distance_matrix.png?raw=true" width="600"></center>

# %% [markdown]
# Сгенерируйте множество, состоящее из $K$ временных рядов некоторой длины $n$. Вычислите матрицы евклидовых и DTW расстояний между ними. Проверьте реализованные вами методы, сравнив свои результаты с результатами функции [`pairwise_distance()`](https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.distances.pairwise_distance.html) из библиотеки *sktime*.

# %%
def test_matrices(matrix1 : np.ndarray, matrix2 : np.ndarray) -> None:
    """
    Check whether your matrix function is implemented correctly

    Parameters
    ----------
    matrix1 : distance matrix calculated by sktime
    matrix2 : distance matrix calculated by your function
    """

    np.testing.assert_equal(matrix1.round(5), matrix2.round(5), 'Matrices are not equal')

# %%
random.seed(1)
K, n = 8, 40
ts_matrix = np.vstack([random_walk(n) for _ in range(K)])

ed_matrix = PairwiseDistance(metric="euclidean", is_normalize=False).calculate(ts_matrix)
dtw_matrix = PairwiseDistance(metric="dtw", is_normalize=False).calculate(ts_matrix)

test_matrices(pairwise_distance(ts_matrix, metric="euclidean"), ed_matrix)
test_matrices(pairwise_distance(ts_matrix, metric="dtw"), dtw_matrix)
print("Distance matrices match sktime")
# Out:
# Distance matrices match sktime

# %% [markdown]
# ### **Задача 4.**
# Далее рассмотрим задачу иерархической кластеризации временных рядов, где будет использоваться предвычисленная матрица расстояний.
#
# Для этого сначала загрузите набор временных рядов CBF из файла *CBF_TRAIN.txt*, который располагается в директории *./datasets/part1*. Каждая строка данного файла содержит целевую переменную (класс: 0, 1 или 2) в первом столбце и временной ряд в остальных столбцах. Набор CBF является синтетическим и включает в себя 30 временных рядов,  каждый из которых принадлежит к одному из трех классов.

# %%
url = './datasets/part1/CBF_TRAIN.txt'

data = read_ts(url)
# read_ts возвращает массив: столбец 0 — класс, остальные столбцы — ряд.
ts_set = data[:, 1:]
labels = data[:, 0]

# %% [markdown]
# Выполните визуализацию по одному временному ряду из каждого класса. Для этого используйте функцию `plot_ts()` из модуля *plots.py*.

# %%
class_ids = np.unique(labels)
examples = np.vstack([ts_set[labels == class_id][0] for class_id in class_ids])
plot_ts(examples, "CBF: one series from each class")
# Out:
# <div style="height:400px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="3830cfe2-6c57-4930-9223-2b7341721458" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3830cfe2-6c57-4930-9223-2b7341721458")) {                    Plotly.newPlot(                        "3830cfe2-6c57-4930-9223-2b7341721458",                        [{"line":{"width":3},"name":"Time series 0","x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJygpKissLS4vMDEyMzQ1Njc4OTo7PD0+P0BBQkNERUZHSElKS0xNTk9QUVJTVFVWV1hZWltcXV5fYGFiY2RlZmdoaWprbG1ub3BxcnN0dXZ3eHl6e3x9fn8="},"y":{"dtype":"f8","bdata":"x4E2vbS23b+nqSvA88Lhv6MYxReS+Oq\u002fylULcGq1679HcfFk9fbtvyAdaE8TJ+q\u002fbsmBiQXf0L9GnRRB9yD0v+AlgoKcAfS\u002fKbSs+8di7b\u002fokEiZ3IHtvzmmvJDtgO+\u002frTpheNub9L\u002fri4S2nEvyv9G+qJMiyPC\u002f\u002fJ3UNHti179rkJPT6B\u002fmvz21+uqqYO+\u002fFYLJSwa5779AGcK1A2Psv3k6V5QSwvG\u002f9vhzwGSZ6L+EXiRZLCrwv61OMXuXGuu\u002flhtWAnM+9b\u002fCdBAqJ9Dmv93qOel9w\u002fS\u002fHqqEgq1N9T9FFsSbkPHtPw41ZQLZxvM\u002fgcqdPqfl8D+y6OeX0iTtPzAD334K8fU\u002fhisUp2L87T+eJ32lHCHtP15ckTV2y+0\u002fUekWcIXm9z8azus+thv1Pz7FFidjgfM\u002fl8O0kPxY7j9PcV6Uh6LFPytmxtPZRu8\u002f1gv0P6+u8z8vgkqFRkriP6MZkxf8Cug\u002fSS1SMHzH7j\u002ft515xggDpP1fNc0S+q\u002fE\u002fUMLxIU0B8D82w7I+ip\u002fhP5P8LaY+NdE\u002fiW4HNCIC8j+OXDelvDbxP1EWvr7WJfE\u002f3i5FA8J48j8bFychBU3oP\u002fbLzHETWsM\u002fauENxA1T8D961Kk8yx30P4gvE0VIHfA\u002fhfpMrEKZ8j\u002fOJOKUVo\u002fqP+oI4Gbxwvc\u002ffgeaKnOu8T8erFotC6H4P2N3JtmP2fE\u002fwhcmUwVD\u002fj9xYCgWrj32P6d0sP7PgfI\u002fVGUpo9s8+D9qOMAnMSP6P0WYR6On7ek\u002f\u002fyJHvjun5T\u002fY1k\u002f\u002fWbPmPyVGhaBZyPU\u002f2\u002fI224H\u002f9D9Nn\u002fxhdO7iP2IGMlQon+o\u002fDPxNzYqN8T+3530M6+DuP\u002f30wEMooe0\u002fTny1ozjH8z9+hRYjXPLxPy5Tk+AN6e0\u002fCFtHsMx28z9HAaJgxrT5v8Zy6IBmCOO\u002fgT2JfFU26L+BuyaDJx3iv1M1rG+BwOS\u002fJSoKqvwB5b\u002fO+0FVMwjhv5hZnf\u002fLc72\u002f6cuYo0NX4r9k0yGiXlHhv6rVNkkcZ+a\u002fi6n0E84u87+B5WtDg3zuv0V+Py3t8e+\u002fU7U4vlFm6r+2uiBLtF7Yv7r8f4OTgN6\u002f0gO8WFo+47+lfO8MpqPXv8eRGE7jyPS\u002furx7eH1j7b8fDOE9rDz0vwxBihH0ve+\u002fBV3Sg0jH6b+AM+fPbXjtvy9wFoJecNe\u002fupnZAM8q1r89VjppK8DwvyokkWTzRO2\u002fGffuqJQr7b\u002fluzGQqZPvv3sLNVTWgPO\u002fBK\u002fx9KXy4L8Z0wJqIEz1v5\u002fNqs\u002fVVvG\u002fx2Rx\u002f5FJ8L+BGFN2G1Dtv8pLo24MJvK\u002f\u002fr2x83hy7b+QFmcMc0Lpv0eqczVHcOS\u002fOWHCaFbW7r8I1idvNuzzvw=="},"type":"scatter"},{"line":{"width":3},"name":"Time series 1","x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJygpKissLS4vMDEyMzQ1Njc4OTo7PD0+P0BBQkNERUZHSElKS0xNTk9QUVJTVFVWV1hZWltcXV5fYGFiY2RlZmdoaWprbG1ub3BxcnN0dXZ3eHl6e3x9fn8="},"y":{"dtype":"f8","bdata":"6mgLvh8t8r8ul+iHbBv1v5zF5j6Ug\u002f2\u002fOis3i\u002fY86b9dkrnoGhzQv5XMVgM5zfe\u002fsXks6INm5b8RSYDcdsjVvxU7Gof6vfC\u002fbf8tdU7707+3sBMDyYDwv9\u002fA5EaRNfO\u002fP9J1G7PQ5L+n5EEf0en5vyH5MYOEatq\u002flfPF3ovP8L8fwlMjT83yv4eMBY2yYdu\u002fAMBWrlw0879RiSXE4Mriv+YetwSFxvK\u002fIfgIyqdm1L96CQTwBVz7v6pQk8\u002fhEPu\u002foxS+CGTg8L9MfWoGAk71vzpRGoOxEua\u002fuPiIVvbW57+m6HGtMHzvvySBBps6D\u002fO\u002fl\u002fVqmW+R4b+THdlkprfiP+Nmn2T+8+K\u002fo6lDE81o6L9hFZByBxzSv2o74JlU3du\u002fmJLds0snwD+EN\u002feZqw3VvxssnKT5Q\u002fe\u002fPZBIHRXm4L91BGv6vki3vw+riU9LPbQ\u002fsq+G1WlO8r8WJGwu7Yrwv8aPShTOLN2\u002fiplUn3Ei4b+0ABLy5hXBv7L0whnT\u002fs2\u002fXNrb8x14qj\u002febFrG2XbmP6AXzU4vRs4\u002fUjQo\u002fTHr3D+HlJfjsh3nv+irmtZc5PO\u002fyBUP1pyP3T\u002fgOCFbMwXhP6EmfrU4Hdc\u002fnEh\u002fG6Egoj9qCDuDji\u002fUP5fvbNH6QuE\u002fv6Qp6f49xz8GZBKiOmXYv0AxZtZIzqO\u002ftuHq33my4j\u002f5DZdF9rvUvwv0fBJHOp0\u002f1FO7kT85vL+bokw4LkK3v781h9ZQC9Y\u002fv6a9d4rL0j8dwEs+sKLoP6Ueu26+j90\u002f7I6ct3du0D8nAFpOnaLyP\u002fMobHFTxOM\u002fn3r\u002feuC+zr8RTLnrOo7lP9tCoa9q2so\u002f6PO0cBcJ6D\u002fQ9kPHaePwP+PxcN\u002fDVZS\u002fYSqJLqB+2j9578H ...

# %% [markdown]
# Далее самостоятельно реализуйте класс `TimeSeriesHierarchicalClustering` из модуля *clustering.py*, который выполняет иерархическую кластеризацию временных рядов.
#
# Перед тем как приступить к реализации, изучите скелет этого класса. Реализуйте метод `fit()`, выполняющий кластеризацию данных на основе предвычисленной матрицы расстояний, которая передается в данный метод. Поскольку реализовать иерархическую кластеризацию довольно сложно, используйте готовую реализацию [`AgglomerativeClustering`](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html) из *sklearn*.
#
# Выполните иерархическую кластеризацию загруженных временных рядов CBF для двух функций расстояния: евлидовой метрики и DTW меры.
# Для этого сначала найдите матрицы расстояний между временными рядами, используя класс `PairwiseDistance`, и передайте каждую матрицу в метод `fit()` для кластеризации.
# Далее выполните визуализацию результатов в виде дендрограмм с помощью метода `plot_dendrogram()`, передав исходный набор временных рядов и их метки.

# %%
D_ed = PairwiseDistance(metric="euclidean", is_normalize=False).calculate(ts_set)
D_dtw = PairwiseDistance(metric="dtw", is_normalize=False).calculate(ts_set)

hc_ed = TimeSeriesHierarchicalClustering(n_clusters=3, method="complete")
hc_dtw = TimeSeriesHierarchicalClustering(n_clusters=3, method="complete")
labels_ed = hc_ed.fit_predict(D_ed)
labels_dtw = hc_dtw.fit_predict(D_dtw)

hc_ed.plot_dendrogram(pd.DataFrame(ts_set.T), labels, title="CBF, Euclidean")
hc_dtw.plot_dendrogram(pd.DataFrame(ts_set.T), labels, title="CBF, DTW")

# %% [markdown]
# Сравните результаты иерархической кластеризации, полученные при двух различных функций расстояния, с помощью силуэтного коэффициента. Для этого используйте функцию [`silhouette_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html) из библиотеки *sklearn*, передав в нее предвычисленную матрицу расстояний и предсказанные метки.
#
# **Силуэтный коэффициент** – метрика, которая оценивает качество кластеризации на основе исходной выборки и результатов кластеризации без необходимости знания об истинных метках объектов.
#
# Силуэтный коэффициент для выборки показывает, насколько среднее расстояние до объектов своего кластера отличается от среднего расстояния до объектов других кластеров. Пусть дана выборка $X$, состоящая из $N$ объектов. Предположим, что объекты этой выборки были разбиты на кластеры $c_1, ... c_K$, $c_i \in C$, с помощью некоторого алгоритма кластеризации. Тогда силуэтный коэффициент для выборки будет вычисляться следующим образом:
#
# \begin{equation}
# sil\_coef = \frac{1}{N} \sum_{c_k \in C} \sum_{x_i \in c_k} \frac{b(x_i, c_k) - a(x_i, c_k)}{\max(a(x_i, c_k), b(x_i, c_k))},
# \end{equation}
#
# где $a(x_i, c_k)$ – среднее расстояние от объекта $x_i \in c_k$ до других объектов из этого же кластера $c_k$; <br> $b(x_i, c_k)$  – среднее расстояние от объекта $x_i \in c_k$ до объектов из другого кластера $c_l$, $k \neq l$.
#
# Силуэтный коэффициент принимает значения от  −1  до  1:
# *   –1 означает, что кластеры плохие, размытые;
# *   0 означает, что кластеры накладываются друг на друга;
# *   1 означает, что кластеры плотные и хорошо отделены друг от друга.
#
# Таким образом, чем ближе значение коэффициента к 1, тем лучше кластеризованы данные.

# %%
sil_ed = silhouette_score(D_ed, labels_ed, metric="precomputed")
sil_dtw = silhouette_score(D_dtw, labels_dtw, metric="precomputed")
print(f"Silhouette Euclidean: {sil_ed:.4f}")
print(f"Silhouette DTW: {sil_dtw:.4f}")
# Out:
# Silhouette Euclidean: 0.1804
# Silhouette DTW: 0.3881

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Проанализируйте полученные результаты кластеризации с помощью построенных дендрограмм и вычисленных силуэтных коэффициентов. Какая, на ваш взгляд, функция расстояния показала лучший результат и почему? Укажите, в каких случаях более предпочтительно использовать DTW меру, чем евклидову метрику.

# %% [markdown]
# Лучший результат дала DTW: силуэтный коэффициент 0.388 против 0.180 у евклидовой метрики.
#
# Классы CBF отличаются положением характерного участка во времени. Евклидова метрика сравнивает отсчёты с одним номером и воспринимает сдвиг как большое расстояние. DTW выравнивает ряды и сравнивает форму.
#
# DTW предпочтительнее, когда одна и та же форма сдвинута, растянута или идёт с разной скоростью. Евклидова метрика уместна, когда ряды уже стоят на общей шкале времени и важны значения в одни и те же моменты.

# %% [markdown]
# ## **Часть 2.** $Z$-нормализация временных рядов.

# %% [markdown]
# ### **Задача 5.**
# Реализуйте функцию вычисления нормализованного евклидова расстояния между временными рядами `norm_ED_distance()` в модуле *metrics.py* и проверьте правильность своей реализации, сравнив полученные результаты с результатами функции [`ed_distance()`](https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.distances.euclidean_distance.html) из библиотеки *sktime*, в которую необходимо передать <u>нормализованные</u> временные ряды. Для нормализации временных рядов используйте функцию `z-normalize()` из *utils.py*.  Для проверки можно использовать синтетические временные ряды из первой части или заново их сгенерировать.
#
# **Нормализованная евклидова метрика** между двумя временными рядами $T_1$ и $T_2$ длины $n$ вычисляется следующим образом:
#
# \begin{equation}
# 	\text{ED}_{norm}(T_1, T_2) = \sqrt {\Big|\; 2n\left(1-\dfrac{<T_1, T_2> - \; n \; \cdotp \mu_{T_1} \; \cdotp \mu_{T_2}}{n \; \cdotp \sigma_{T_1} \; \cdotp \sigma_{T_2}}\right)\Big|},
# \end{equation}
#
# где $<T_1, T_2>$ – скалярное произведение временных рядов, $\mu_{T_1}$ и $\mu_{T_2}$, $\sigma_{T_1}$ и $\sigma_{T_2}$ – среднее арифметическое и стандартное отклонение временных рядов соответственно.
#
# **Среднее арифметическое** $\mu_T$ и **стандартное отклонение** $\sigma_T$ временного ряда $T$ длины $n$ вычисляются по следующим формулам:
#
# \begin{equation}
# 	\mu_{T} = \frac{1}{n}\sum\limits_{i=1}^{n} t_{i}, \\[1em]
# 	\sigma_{T} = \sqrt{\frac{1}{n}\sum\limits_{i=1}^{n} t_i^2-\mu_{T}^2}.
# \end{equation}

# %%
test_distances(
    euclidean_distance(z_normalize(ts1), z_normalize(ts2)),
    norm_ED_distance(ts1, ts2),
)
print("Normalized ED distance:", norm_ED_distance(ts1, ts2))
# Out:
# Normalized ED distance: 8.549601822475577

# %% [markdown]
# ### **Задача 6.**
# Далее убедимся, что выполнение $z$-нормализации на этапе предобработки данных имеет важное значение и может повысить точность решаемой задачи.
#
# В данном задании вы продолжите решать задачу иерархической кластеризации. В качестве данных будут использоваться два временных ряда из набора данных [BIDMC](https://physionet.org/content/chfdb/1.0.0/). Набор BIDMC состоит из записей ЭКГ-сигналов, снятых с 15 пациентов с сердечной недостаточностью тяжелой степени.
#
# Загрузите два временных ряда и визуализируйте их с помощью функции `plot_ts()` из модуля *plots.py*.

# %%
url1 = './datasets/part2/chf10.csv'
ts1 = read_ts(url1)

url2 = './datasets/part2/chf11.csv'
ts2 = read_ts(url2)

# %%
ts_set = np.concatenate((ts1, ts2), axis=1).T

# %%
plot_ts(ts_set)
# Out:
# <div style="height:400px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="e124e07d-39cf-4df0-8b8e-8c46f5303cf8" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e124e07d-39cf-4df0-8b8e-8c46f5303cf8")) {                    Plotly.newPlot(                        "e124e07d-39cf-4df0-8b8e-8c46f5303cf8",                        [{"line":{"width":3},"name":"Time series 0","x":{"dtype":"i2","bdata":"\\u002fAD9AP4A\u002fwAAAQEBAgEDAQQBBQEGAQcBCAEJAQoBCwEMAQ0BDgEPARABEQESARMBFAEVARYBFwEYARkBGgEbARwBHQEeAR8BIAEhASIBIwEkASUBJgEnASgBKQEqASsBLAEtAS4BLwEwATEBMgEzATQBNQE2ATcBOAE5AToBOwE8AT0BPgE\...\u002fgH\...\u002fAsACwQLCAsMCxALFAsYCxwLIAskCygLLAswCzQLOAs8C0ALRAtIC0wLUAtUC1gLXAtgC2QLaAtsC3ALdAt4C3wLgAuEC4gLjAuQC5QLmAucC6ALpAuoC6wLsAu0C7gLvAvAC8QLyAvMC9AL1AvYC9wL4AvkC+gL7AvwC\\\u002fID8wP0A\u002fUD9gP3A\u002fgD+QP6A\u002fsD\u002fAP9A\u002f4D\u002fwMABAEEAgQDBAQEBQQGBAcECAQJBAoECwQMBA0EDgQPBBAEEQQSBBMEFAQVBBYEFwQYBBkEGgQbBBwEHQQeBB8EIAQhBCIEIwQkBCUEJgQnBCgEKQQqBCsELAQtBC4ELwQwBDEEMgQzBDQENQQ2BDcEOAQ5BDoEOwQ8BD0EPgQ\...\u002fgT\...\u002fBcAFwQXCBcMFxAXFBcYFxwXIBckFygXLBcwFzQXOBc8F0AXRBdIF0wXUBdUF1gXXBdgF2QXaBdsF3AXdBd4F3wXgBeEF4gXjBeQF5QXmBecF6AXpBeoF6wXsBe0F7gXvBfAF8QXyBfMF9AX1BfYF9wX4BfkF+gX7BfwF\\\u002fAb9Bv4G\u002fwYABwEHAgcDBwQHBQcGBwcHCAcJBwoHCwcMBw0HDgcPBxAHEQcSBxMHFAcVBxYHFwcYBxkHGgcbBxwHHQceBx8HIAchByIHIwckByUHJgcnBygHKQcqBysHLActBy4HLwcwBzEHMgczBzQHNQc2BzcHOAc5BzoHOwc8Bz0HPgc\...\u002fEH8gfzB\u002fQH9Qf2B\u002fcH+Af5B\u002foH+wf8B\u002f0H\u002fgf\...\u002fCMAIwQjCCMMIxAjFCMYIxwjICMkIygjLCMwIzQjOCM8I0AjRCNII0wjUCNUI1gjXCNgI2QjaCNsI3AjdCN4I3wjgCOEI4gjjCOQI5QjmCOcI6AjpCOoI6wjsCO0I7gjvCPAI8QjyCPMI9Aj1CPYI9wj4CPkI+gj7CPwI\u002fQj+CP8IAAkBCQIJAwkECQUJBgkHCQgJCQkKCQsJDAkNCQ4JDwkQCRE ...

# %% [markdown]
# Разделите каждый временной ряд на непересекающиеся подпоследовательности с помощью техники скользящего окна. Для этого используйте функцию `sliding_window()` из модуля *utils.py*, передав в нее временной ряд, заданную длину подпоследовательности и величину шага. В нашем случае, величина шага равна длине подпоследовательности.

# %%
m = 125
subs_set1 = sliding_window(ts_set[0], m, m-1)
subs_set2 = sliding_window(ts_set[1], m, m-1)

# %% [markdown]
# Сформируйте множество всех подпоследовательностей, извлеченных из двух временных рядов, и массив меток подпоследовательностей в соответствии с их принадлежностью к временному ряду.

# %%
subs_set = np.concatenate((subs_set1[0:15], subs_set2[0:15]))
labels = np.array([0]*subs_set1[0:15].shape[0] + [1]*subs_set2[0:15].shape[0])

# %% [markdown]
# Добавьте в класс `PairwiseDistance` из модуля *pairwise_distance.py* возможность вычисления нормализованной евклидовой метрики между временными рядами. Если матрица расстояний строится для нормализованных временных рядов на основе евклидовой метрики, то должна вызываться функция `norm_ED_distance()`. Для остальных метрик/мер схожести перед нахождением матрицы расстояний временные ряды должны подтвергаться $z$-нормализации с помощью функции `z_normalize()` из модуля *utils.py*.
#
# Далее выполните иерархическую кластеризацию подпоследовательностей двух временных рядов с использованием предварительно построенных матриц расстояний на основе классической и нормализованной евклидовой метрики.

# %%
D_ed = PairwiseDistance(metric="euclidean", is_normalize=False).calculate(subs_set)
D_norm = PairwiseDistance(metric="euclidean", is_normalize=True).calculate(subs_set)

hc_ed = TimeSeriesHierarchicalClustering(n_clusters=2, method="complete")
hc_norm = TimeSeriesHierarchicalClustering(n_clusters=2, method="complete")
labels_ed = hc_ed.fit_predict(D_ed)
labels_norm = hc_norm.fit_predict(D_norm)

hc_ed.plot_dendrogram(pd.DataFrame(subs_set.T), labels, title="ECG windows, Euclidean")
hc_norm.plot_dendrogram(pd.DataFrame(subs_set.T), labels, title="ECG windows, normalized Euclidean")

# %% [markdown]
# Вычислите силуэтные коэффициенты для оценки качества кластеризации с нормализацией и без нее, как это было сделано в задаче 4 части 1.

# %%
sil_ed = silhouette_score(D_ed, labels_ed, metric="precomputed")
sil_norm = silhouette_score(D_norm, labels_norm, metric="precomputed")
print(f"Silhouette without normalization: {sil_ed:.4f}")
print(f"Silhouette with normalization: {sil_norm:.4f}")
# Out:
# Silhouette without normalization: 0.4183
# Silhouette with normalization: 0.3275

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Сравните полученные результаты кластеризации с помощью построенных дендрограмм и вычисленных силуэтных коэффициентов. Позволила ли $z$-нормализации временных рядов повысить качество кластеризации?

# %% [markdown]
# На этих окнах ЭКГ z-нормализация качество не повысила: силуэт 0.418 без неё и 0.328 с ней.
#
# Окна одного пациента близки по форме, а две записи отличаются ещё и амплитудой. Без нормализации евклидова метрика использует этот масштаб. После z-нормализации остаётся только форма, а формы циклов похожи, поэтому кластеры разделяются хуже.

# %% [markdown]
# ## **Часть 3.** Классификация изображений, представленных в виде временных рядов.

# %% [markdown]
# ### **Задача 7.**
# В данном задании вам предстоит выполнить преобразование изображения, на котором находится некоторый объект, во временной ряд. Для этого вы реализуете один из существующих методов, предложенный в [статье Кеога и др](https://dl.acm.org/doi/10.5555/1182635.1164203).
#
# Данный метод заключается в том, что сначала на изображении выполняется поиск контура $E = \{e_i\}_{i=1}^L$, где $e_i$ – точки контура, и центра масс объекта $O$. Затем берутся точки, расположенные на контуре объекта, следующим образом.
#
# Рассмотрим луч $OP$ с началом в центре масс объекта $O$, направление которого совпадает с положительным направлением оси Ox (см. рисунок). Далее выполняется поворот против часовой стрелки луча $OP$ вокруг центра масс $O$ на некоторый заданный угол $α$, $1° \leqslant α \leqslant 360°$. Поворот луча будет осуществляться до тех пор, пока луч не пройдет полный оборот. Все точки $P = \{P_i\}_{i=1}^K$, $P_i \in E$, $K = \lfloor \frac{360°}{α} \rfloor$, образованные пересечением луча $OP$ с контуром $E$ во время поворота, будут являться искомыми.
#
# На завершающем шаге метода вычисляются расстояния между центром масс объекта $O$ и найденными точками на контуре $P$. В качестве функции расстояния может быть использовано манхэттенское или евклидово расстояние. Полученные расстояния будут формировать временной ряд $T$ длины $K$:
# \begin{equation}
# T = \{t_i\}_{i=1}^K,\;где \; t_i = dist(O, P_i), \; P_i \in P.
# \end{equation}
#
# \
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/01%20Basics/img/image2ts.png?raw=true" width="1000"></center>

# %% [markdown]
# Поскольку часть 3 предполагает работу с изображениями, то вы будете использовать для реализации некоторых частей кода библиотеку компьютерного зрения *cv2*. Для поиска всех необходимых функций рекомендуем воспользоваться [документацией библиотеки cv2](https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html).
#
# Загрузите изображение *example.tif* из директории *./datasets/part3* и выполните его визуализацию с помощью соответствующих функций из библиотеки *cv2*.

# %%
img = cv2.imread("./datasets/part3/example.tif")
plt.figure(figsize=(6, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("example.tif")
plt.show()
# Out:
# [ WARN:0@4118.186] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null

# %% [markdown]
# За конвертацию изображения во временной ряд с помощью описанного выше метода отвечает функция `image2ts()` из модуля *image_converter.py*. Прежде чем исходное изображение будет преобразовано во временной ряд, сначала оно должно пройти этап предварительной обработки. Предварительная обработка включает в себя следующие шаги:
#
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/01%20Basics/img/image_preprocessing.png?raw=true" width="1000"></center>
#
# Предобработка изображения в `image2ts()` осуществляется с помощью функции `_img_preprocess()`. Реализуйте в данной функции все представленные на диаграмме шаги предварительной обработки средствами библиотеки *cv2*. Промежуточные результаты должны совпадать с представленными на диаграмме.
#
# Далее выполните конвертацию изображения во временной ряд, передав в функцию `image2ts()` следующие заданные вами аргументы:
# *   исходное загруженное изображение;
# *   шаг угла поворота;
# *   параметр, определяющий нужно или нет визуализировать изображение с выделенными на нем контуром, центром масс и лучами, проведенными из центра.
#
# Визуализируйте полученный временной ряд.

# %%
angle_step = 20
visualize = True

ts = image2ts(img, angle_step, visualize)
plot_ts(np.array([ts]), "Time series representation of image")
# Out:
# <div style="height:400px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="1bd062c1-c6fa-45e1-bf56-6db3ea543226" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1bd062c1-c6fa-45e1-bf56-6db3ea543226")) {                    Plotly.newPlot(                        "1bd062c1-c6fa-45e1-bf56-6db3ea543226",                        [{"line":{"width":3},"name":"Time series 0","x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAR"},"y":{"dtype":"f8","bdata":"AAAAAABgckAAAAAAABB9QAAAAAAAgIJAAAAAAADYhEAAAAAAAFCCQAAAAAAAMH9AAAAAAACgfkAAAAAAACCBQAAAAAAAIHpAAAAAAADQdEAAAAAAALB0QAAAAAAAMH9AAAAAAADwekAAAAAAADCBQAAAAAAAoINAAAAAAACwfEAAAAAAAGB3QAAAAAAAYHhA"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks": ...

# %% [markdown]
# ### **Задача 8.**
#
# Выполните классификацию изображений, представленных в виде временных рядов, с помощью метода $k$ ближайших соседей (kNN).
#
# **Метод $k$ ближайших соседей (kNN)** – алгоритм классификации, заключающийся в вычислении сходства между объектами на основе некоторой заданной метрики/меры схожести. Классифицируемый объект относится к тому классу, к которому принадлежит большинство из его $k$ соседей ($k$ ближайших к нему объектов из обучающей выборки).
#
# Для классификации на основе алгоритма kNN необходимо выполнить следующие шаги:
#
# 1. Загрузить обучающую и тестовую выборки.
#
# 2. Задать параметр алгоритма $k$, где $k$ – количество ближайших соседей, $k \in \mathbb N^*$.
#
# 3. Для каждого объекта из тестовой выборки выполнить следующее:
#
#     3.1. Вычислить расстояние до всех объектов из обучающей выборки на основе заданной метрики/меры схожести.
#
#     3.2. Отсортировать в порядке возрастания найденные расстояния.
#
#     3.3. Найти $k$ ближайших соседей, взяв первые $k$ минимальные расстояния из отсортированного массива расстояний.
#
#     3.4. Назначить объекту из тестовой выборки наиболее часто встречающийся класс найденных ранее ближайших соседей.
#
#
# Для этого задания вам предлагается набор данных, который содержит изображения листьев четырех различных пород деревьев: дуб, ольха, ива и липа. Набор данных состоит из обучающей и тестовой выборок, включающих по 15 и 10 изображений листьев на класс соответственно. Для составления этого набора данных изображения были взяты из [Swedish Leaf Dataset](https://www.cvl.isy.liu.se/en/research/datasets/swedish-leaf/).
#
# Загрузите изображения из обучающей и тестовой выборок, а также их метки, используя `read_images()` и `read_ts()` соответственно.
# Выполните визуализацию прецедентов выборки с помощью функции `plot_images()`.

# %%
def read_images(dir: str) -> list[np.ndarray]:
    """
    Load all images from a directory

    Parameters
    ----------
    dir: directory path

    Returns
    -------
    images: images from a directory
    """

    images = []
    for img_path in sorted(glob.glob(dir)):
        cv_img = cv2.imread(img_path)
        images.append(cv_img)

    return images

# %%
def plot_images(images: list[np.ndarray], labels: np.ndarray, class_names: list[str]) -> None:
    """
    Plot some images from dataset

    Parameters
    ----------
    images: dataset of images
    labels: labels of images
    class_names: class names of images
    """

    rows = 2
    columns = 4

    fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*2, rows*3))

    for num in range(1, rows*columns+1):
        fig.add_subplot(rows, columns, num)
        idx = num - 1
        plt.imshow(images[idx], aspect='auto')
        plt.title(f'{class_names[labels[idx]]}', fontsize=10)

    fig.tight_layout()

    for idx, ax in enumerate(axes.flat):
        ax.set_xticks([])
        ax.set_yticks([])

# %%
train_set_path = "./datasets/part3/train_set_leaves/*.tif"
test_set_path = "./datasets/part3/test_set_leaves/*.tif"

train_images = read_images(train_set_path)
test_images = read_images(test_set_path)

train_label_path = './datasets/part3/train_set_leaves/train_label.csv'
test_label_path = './datasets/part3/test_set_leaves/test_label.csv'

train_labels = read_ts(train_label_path)
train_labels = train_labels.reshape(-1).astype('int32')

test_labels = read_ts(test_label_path)
test_labels = test_labels.reshape(-1).astype('int32')
# Out:
# [ WARN:0@4118.372] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.380] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.382] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.384] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.385] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.387] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.388] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.390] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.392] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.394] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.403] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.406] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.410] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.412] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.421] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.424] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.430] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.439] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.442] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.447] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.451] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.455] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.458] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.464] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.469] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.473] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.478] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.480] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.482] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.484] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.487] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.489] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.492] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.495] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.499] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.502] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.506] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.509] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.512] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.514] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.517] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.519] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.522] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.525] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.527] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.530] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.535] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.536] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.540] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.545] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.553] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.559] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.564] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.573] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.575] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.580] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.582] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.589] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.591] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.593] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.599] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.605] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.617] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.624] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.629] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.635] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.638] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.645] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.650] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.657] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.659] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.661] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.668] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.672] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.675] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.688] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.701] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.703] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.705] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.706] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.708] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.710] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.716] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.718] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.719] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.720] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.727] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.728] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.733] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.737] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.745] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.748] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.754] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.758] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.762] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.766] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.771] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.776] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.782] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null
# [ WARN:0@4118.787] global grfmt_tiff.cpp:123 TIFF_Warning TIFFFetchNormalTag: ASCII value for tag "ImageDescription" does not end in null byte. Forcing it to be null

# %%
class_names = ['Quercus (дуб)', 'Alnus (ольха)', 'Salix (ива)', 'Tilia (липа)']
plot_images(train_images, train_labels, class_names)

# %% [markdown]
# Выполните преобразование изображений обучающей и тестовой выборок во временные ряды с помощью функции `image2ts()`.

# %%
angle_step = 20
X_train = np.vstack([image2ts(image, angle_step, False) for image in train_images])
X_test = np.vstack([image2ts(image, angle_step, False) for image in test_images])
print(X_train.shape, X_test.shape)
# Out:
# (60, 18) (40, 18)

# %% [markdown]
# Для классификации временных рядов методом $k$ ближайших соседей вам необходимо использовать класс `TimeSeriesKNN` из модуля *classification.py*.
# Реализуйте метод `fit()` в классе `TimeSeriesKNN`, который выполняет поиск для каждого элемента из тестовой выборки $k$ ближайших соседей и назначает им тот класс, который является часто встречающимся среди классов ближайших соседей. В качестве параметров в метод `fit()` передается тестовая выборка. Вычислите точность классификации по метрике accuracy с помощью функции `calculate_accurary()` из модуля *classification.py*.

# %%
n_neighbors = 6
metric = 'euclidean'
metric_params = {'normalize': True}

clf = TimeSeriesKNN(n_neighbors=n_neighbors, metric=metric, metric_params=metric_params)
clf.fit(X_train, train_labels)
y_pred_ed = clf.predict(X_test)
acc_ed = calculate_accuracy(test_labels, y_pred_ed)
print(f"kNN Euclidean accuracy: {acc_ed:.4f}")
# Out:
# kNN Euclidean accuracy: 0.9000

# %%
metric = 'dtw'
metric_params = {'normalize': True}

clf = TimeSeriesKNN(n_neighbors=n_neighbors, metric=metric, metric_params=metric_params)
clf.fit(X_train, train_labels)
y_pred_dtw = clf.predict(X_test)
acc_dtw = calculate_accuracy(test_labels, y_pred_dtw)
print(f"kNN DTW accuracy: {acc_dtw:.4f}")
# Out:
# kNN DTW accuracy: 0.9000

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Проанализируйте результаты и сделайте выводы.

# %% [markdown]
# При k = 6 и шаге угла 20° точность на тестовых листьях одинаковая: 0.90 и для евклидовой метрики, и для DTW.
#
# Ряды уже выровнены по углу: луч каждый раз стартует вдоль оси Ox, поэтому поточечное сравнение и выравнивание DTW дают один и тот же результат. Оставшиеся 10% ошибок — листья с похожим контуром.
